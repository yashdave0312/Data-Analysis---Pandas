# %%
import pandas as pd

# %%
s=pd.Series([67,89,45,78,90])

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
print(s)
# Out:
# 0    67
# 1    89
# 2    45
# 3    78
# 4    90
# dtype: int64

# %%
s2=pd.Series([67,89,45,78,90],index=['Yash','Krunal','Meet','Om','Bhaumik'])

# %%
s2
# Out:
# Yash       67
# Krunal     89
# Meet       45
# Om         78
# Bhaumik    90
# dtype: int64

# %%
s2['Yash']
# Out:
# np.int64(67)

# %%
data={
    "name":['Yash','Somya','Shruti'],
    "marks":[87,89,95],
    "city":['Dahanu','Khergam','Jaipur']
}

# %%
s3=pd.DataFrame(data)

# %%
s3
# Out:
#      name  marks     city
# 0    Yash     87   Dahanu
# 1   Somya     89  Khergam
# 2  Shruti     95   Jaipur

# %%
data["name"][0]
# Out:
# 'Yash'
