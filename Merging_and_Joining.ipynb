# %%
import pandas as pd

# %%
employees = pd.DataFrame({
    "EmpID": [1, 2, 3],
    "Name": ["Alice", "Bob", "Charlie"],
    "DeptID": [10, 20, 30]
})
 
departments = pd.DataFrame({
    "DeptID": [10, 20, 40],
    "DeptName": ["HR", "Engineering", "Marketing"]
})

# %%
employees
# Out:
#    EmpID     Name  DeptID
# 0      1    Alice      10
# 1      2      Bob      20
# 2      3  Charlie      30

# %%
departments
# Out:
#    DeptID     DeptName
# 0      10           HR
# 1      20  Engineering
# 2      40    Marketing

# %%
pd.merge(employees,departments,on="DeptID")
# Out:
#    EmpID   Name  DeptID     DeptName
# 0      1  Alice      10           HR
# 1      2    Bob      20  Engineering

# %%
pd.merge(employees,departments,on="DeptID",how="left")
# Out:
#    EmpID     Name  DeptID     DeptName
# 0      1    Alice      10           HR
# 1      2      Bob      20  Engineering
# 2      3  Charlie      30          NaN

# %%
pd.merge(employees,departments,on="DeptID",how="right")
# Out:
#    EmpID   Name  DeptID     DeptName
# 0    1.0  Alice      10           HR
# 1    2.0    Bob      20  Engineering
# 2    NaN    NaN      40    Marketing

# %%
pd.merge(employees,departments,on="DeptID",how="outer")
# Out:
#    EmpID     Name  DeptID     DeptName
# 0    1.0    Alice      10           HR
# 1    2.0      Bob      20  Engineering
# 2    3.0  Charlie      30          NaN
# 3    NaN      NaN      40    Marketing

# %%
pd.concat([employees,departments])
# Out:
#    EmpID     Name  DeptID     DeptName
# 0    1.0    Alice      10          NaN
# 1    2.0      Bob      20          NaN
# 2    3.0  Charlie      30          NaN
# 0    NaN      NaN      10           HR
# 1    NaN      NaN      20  Engineering
# 2    NaN      NaN      40    Marketing

# %%
df1 = pd.DataFrame({"Name": ["Alice", "Bob"]})
df2 = pd.DataFrame({"Name": ["Charlie", "David"]})
 
pd.concat([df1, df2])
# Out:
#       Name
# 0    Alice
# 1      Bob
# 0  Charlie
# 1    David

# %%
df1 = pd.DataFrame({"ID": [1, 2]})
df2 = pd.DataFrame({"Score": [90, 80]})
 
pd.concat([df1, df2])
# Out:
#     ID  Score
# 0  1.0    NaN
# 1  2.0    NaN
# 0  NaN   90.0
# 1  NaN   80.0

# %%
df1 = pd.DataFrame({"ID": [1, 2]})
df2 = pd.DataFrame({"Score": [90, 80]})
 
pd.concat([df1, df2], axis=1)
# Out:
#    ID  Score
# 0   1     90
# 1   2     80

# %%
pd.concat([employees,departments], axis=1)
# Out:
#    EmpID     Name  DeptID  DeptID     DeptName
# 0      1    Alice      10      10           HR
# 1      2      Bob      20      20  Engineering
# 2      3  Charlie      30      40    Marketing

# %%
df11=pd.concat([employees,departments]).copy()

# %%
df11
# Out:
#    EmpID     Name  DeptID     DeptName
# 0    1.0    Alice      10          NaN
# 1    2.0      Bob      20          NaN
# 2    3.0  Charlie      30          NaN
# 0    NaN      NaN      10           HR
# 1    NaN      NaN      20  Engineering
# 2    NaN      NaN      40    Marketing

# %%
df11.isnull()
# Out:
#    EmpID   Name  DeptID  DeptName
# 0  False  False   False      True
# 1  False  False   False      True
# 2  False  False   False      True
# 0   True   True   False     False
# 1   True   True   False     False
# 2   True   True   False     False

# %%
df11.isnull().sum()
# Out:
# EmpID       3
# Name        3
# DeptID      0
# DeptName    3
# dtype: int64

# %%
df11.dropna()
# Out:
# Empty DataFrame
# Columns: [EmpID, Name, DeptID, DeptName]
# Index: []

# %%
df11
# Out:
#    EmpID     Name  DeptID     DeptName
# 0    1.0    Alice      10          NaN
# 1    2.0      Bob      20          NaN
# 2    3.0  Charlie      30          NaN
# 0    NaN      NaN      10           HR
# 1    NaN      NaN      20  Engineering
# 2    NaN      NaN      40    Marketing

# %%
df11.fillna(0)
# Out:
#    EmpID     Name  DeptID     DeptName
# 0    1.0    Alice      10            0
# 1    2.0      Bob      20            0
# 2    3.0  Charlie      30            0
# 0    0.0        0      10           HR
# 1    0.0        0      20  Engineering
# 2    0.0        0      40    Marketing
